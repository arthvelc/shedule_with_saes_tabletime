# %%
import pandas as pd

# %% [markdown]
# Leer la tabla desde la Página web

# %%
url = 'https://arthvelc.github.io/shedule_with_saes_tabletime/'
df = pd.read_html(url)

#Obtener el DF correspondiente a la tabla
table = df[0]
table = table[["Asignatura", "Profesor", "Lun", "Mar", "Mie", "Jue", "Vie"]]
table
# Out:
#                           Asignatura                             Profesor  \
# 0   ALGORITMOS Y ESTRUCTURA DE DATOS              JUÁREZ MÉNDEZ ANA BELEM
# 1                     ALGEBRA LINEAL                       NAVA LARA JOEL
# 2                   CALCULO APLICADO                   JUAREZ LEON CARLOS
# 3       MECANICA Y ELECTROMAGNETISMO            ZARATE CARDENAS ALEJANDRO
# 4        INGENIERIA ETICA Y SOCIEDAD           HERNANDEZ GARCIA ROSA ALBA
# 5             FUNDAMENTOS ECONOMICOS             ESTRADA ELIZALDE SERAFIN
# 6   ALGORITMOS Y ESTRUCTURA DE DATOS        MACIAS PEREZ FRANCISCO JAVIER
# 7                     ALGEBRA LINEAL         TIRADO LULE JUDITH MARGARITA
# 8                   CALCULO APLICADO                   JUAREZ LEON CARLOS
# 9       MECANICA Y ELECTROMAGNETISMO            FLORES MERAZ YESICA SONIA
# 10       INGENIERIA ETICA Y SOCIEDAD  CRUZ LAZARO ING. APOLINAR FRANCISCO
# 11            FUNDAMENTOS ECONOMICOS             VILLEGAS NAVARRETE SONIA
# 12  ALGORITMOS Y ESTRUCTURA DE DATOS                   CRUZ GARCIA DANIEL
# 13                    ALGEBRA LINEAL           LEON HERNANDEZ MIGUEL ABEL
# 14                  CALCULO APLICADO                LEVARIO MEDINA SERGIO
# 15      MECANICA Y ELECTROMAGNETISMO                          SIN ASIGNAR
# 16       INGENIERIA ETICA Y SOCIEDAD             GONZALEZ ALBARRAN GISELA
# 17            FUNDAMENTOS ECONOMICOS             VILLEGAS NAVARRETE SONIA
# 18  ALGORITMOS Y ESTRUCTURA DE DATOS              MOSCOSO MALAGON YOSAFAT
# 19                    ALGEBRA LINEAL                  ORTUÑO ARAUJO JESUS
# 20                  CALCULO APLICADO                LEVARIO MEDINA SERGIO
# 21      MECANICA Y ELECTROMAGNETISMO        ESQUIVEL CENTENO JOSE ARMANDO
# 22  ALGORITMOS Y ESTRUCTURA DE DATOS              GONZALEZ GARCIA GUSTAVO
# 23                    ALGEBRA LINEAL            FLORES MERAZ YESICA SONIA
# 24                  CALCULO APLICADO       MONTIEL SANCHEZ ANGEL SALVADOR
# 25      MECANICA Y ELECTROMAGNETISMO        ESQUIVEL CENTENO JOSE ARMANDO
#
#             Lun          Mar          Mie          Jue          Vie
# 0   15:00-16:30          NaN          NaN  15:00-16:30  16:30-18:00
# 1           NaN  15:00-16:30  15:00-16:30          NaN  15:00-16:30
# 2   16:30-18:00          NaN  16:30-18:00  16:30-18:00          NaN
# 3   20:00-21:30  13:30-15:00  20:00-21:30  20:00-21:30          NaN
# 4           NaN  18:30-20:00  18:30-20:00          NaN  18:30-20:00
# 5   18:30-20:00  16:30-18:00          NaN  18:30-20:00          NaN
# 6           NaN  15:00-16:30  15:00-16:30          NaN  15:00-16:30
# 7   16:30-18:00          NaN  16:30-18:00  16:30-18:00          NaN
# 8   18:30-20:00  16:30-18:00          NaN  18:30-20:00          NaN
# 9   15:00-16:30          NaN  13:30-15:00  15:00-16:30  16:30-18:00
# 10  20:00-21:30          NaN  20:00-21:30  20:00-21:30          NaN
# 11          NaN  18:30-20:00  18:30-20:00          NaN  18:30-20:00
# 12  16:30-18:00          NaN  16:30-18:00  16:30-18:00          NaN
# 13  18:30-20:00  16:30-18:00          NaN  18:30-20:00          NaN
# 14          NaN  18:30-20:00  18:30-20:00          NaN  18:30-20:00
# 15  13:30-15:00  15:00-16:30  15:00-16:30          NaN  15:00-16:30
# 16  15:00-16:30          NaN          NaN  15:00-16:30  16:30-18:00
# 17  20:00-21:30          NaN  20:00-21:30  20:00-21:30          NaN
# 18  18:30-20:00  16:30-18:00          NaN  18:30-20:00          NaN
# 19          NaN  18:30-20:00  18:30-20:00          NaN  18:30-20:00
# 20  20:00-21:30          NaN  20:00-21:30  20:00-21:30          NaN
# 21  16:30-18:00          NaN  16:30-18:00  16:30-18:00  16:30-18:00
# 22  20:00-21:30          NaN  20:00-21:30  20:00-21:30          NaN
# 23  16:30-18:00          NaN  16:30-18:00  16:30-18:00          NaN
# 24  15:00-16:30          NaN          NaN  15:00-16:30  16:30-18:00
# 25  18:30-20:00  16:30-18:00          NaN  18:30-20:00  15:00-16:30

# %% [markdown]
# Código para el generador de horarios automático

# %%
horas = ["15:00-16:30", "16:30-18:00", "18:00-19:30", "19:30-21:00", "20:00-21:30"]
for table["Asignatura"]
